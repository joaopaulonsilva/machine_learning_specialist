# %%
# %matplotlib inline

import os

#if using Theano with GPU
#os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
import keras

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root = '/content/drive/MyDrive/imagens'
exclude = ['.ipynb_checkpoints']
train_split, val_split = 0.7, 0.15

categories = [x[0] for x in os.walk(root) if x[0]][1:]
categories = [c for c in categories if c not in [os.path.join(root, e) for e in exclude]]

print(categories)
# Out:
# ['/content/drive/MyDrive/imagens/Dede', '/content/drive/MyDrive/imagens/Dede/.ipynb_checkpoints', '/content/drive/MyDrive/imagens/Didi', '/content/drive/MyDrive/imagens/testes']

# %%
# helper function to load image and return it and input vector
def get_image(path):
    img = image.load_img(path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# %%
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames
              in os.walk(category) for f in filenames
              if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg','.webp','.gif']]
    for img_path in images:
        img, x = get_image(img_path)
        data.append({'x':np.array(x[0]), 'y':c})

# count the number of classes
num_classes = len(categories)

# %%
random.shuffle(data)

# %%
idx_val = int(train_split * len(data))
idx_test = int((train_split + val_split) * len(data))
train = data[:idx_val]
val = data[idx_val:idx_test]
test = data[idx_test:]

# %%
x_train, y_train = np.array([t["x"] for t in train]), [t["y"] for t in train]
x_val, y_val = np.array([t["x"] for t in val]), [t["y"] for t in val]
x_test, y_test = np.array([t["x"] for t in test]), [t["y"] for t in test]
print(y_test)
# Out:
# [0, 2, 0, 0, 0, 2, 2, 0, 2, 2, 2, 0, 2, 0, 0, 2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 0, 0, 2, 0, 2]

# %%
# normalize data
x_train = x_train.astype('float32') / 255.
x_val = x_val.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# convert labels to one-hot vectors
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
print(y_test.shape)
# Out:
# (30, 4)

# %%
# summary
print("finished loading %d images from %d categories"%(len(data), num_classes))
print("train / validation / test split: %d, %d, %d"%(len(x_train), len(x_val), len(x_test)))
print("training data shape: ", x_train.shape)
print("training labels shape: ", y_train.shape)
# Out:
# finished loading 195 images from 4 categories
# train / validation / test split: 136, 29, 30
# training data shape:  (136, 224, 224, 3)
# training labels shape:  (136, 4)

# %%
images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(root) for f in filenames if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg','.webp','.gif']]
idx = [int(len(images) * random.random()) for i in range(8)]
imgs = [image.load_img(images[i], target_size=(224, 224)) for i in idx]
concat_image = np.concatenate([np.asarray(img) for img in imgs], axis=1)
plt.figure(figsize=(16,4))
plt.imshow(concat_image)

# %%
# build the network
model = Sequential()
print("Input dimensions: ",x_train.shape[1:])

model.add(Conv2D(32, (3, 3), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()
# Out:
# Input dimensions:  (224, 224, 3)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 222, 222, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 109, 109, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 109, 109, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 54, 54, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 54, 54, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 52, 52, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 52, 52, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 26, 26, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 24, 24, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 12, 12, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 12, 12, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4608)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           1,028 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 4)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,209,572 (4.61 MB)
#  Trainable params: 1,209,572 (4.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model to use categorical cross-entropy loss function and adadelta optimizer
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=100,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.3074 - loss: 1.3105 - val_accuracy: 0.3793 - val_loss: 0.9561
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4876 - loss: 1.0001 - val_accuracy: 0.6207 - val_loss: 0.6902
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 0.5499 - loss: 0.8537 - val_accuracy: 0.3793 - val_loss: 0.7886
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5623 - loss: 0.7628 - val_accuracy: 0.3793 - val_loss: 0.8460
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.5450 - loss: 0.7976 - val_accuracy: 0.4138 - val_loss: 0.8477
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5352 - loss: 0.7680 - val_accuracy: 0.4483 - val_loss: 0.8357
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.6498 - loss: 0.7207 - val_accuracy: 0.4483 - val_loss: 0.7978
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6100 - loss: 0.7406 - val_accuracy: 0.5517 - val_loss: 0.7443
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6074 - loss: 0.7171 - val_accuracy: 0.3793 - val_loss: 0.7379
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.5999 - loss: 0.7078 - val_accuracy: 0.4138 - val_loss: 0.7840
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6749 - loss: 0.6934 - val_accuracy: 0.4138 - val_loss: 0.8236
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.6377 - loss: 0.7313 - val_accuracy: 0.4483 - val_loss: 0.7816
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6775 - loss: 0.6626 - val_accuracy: 0.4138 - val_loss: 0.7528
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.6850 - loss: 0.6336 - val_accuracy: 0.3793 - val_loss: 0.7537
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7001 - loss: 0.6266 - val_accuracy: 0.4483 - val_loss: 0.7676
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7298 - loss: 0.6077 - val_accuracy: 0.4138 - val_loss: 0.7876
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7125 - loss: 0.5928 - val_accuracy: 0.4828 - val_loss: 0.7698
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7301 - loss: 0.5721 - val_accuracy: 0.5517 - val_loss: 0.7709
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.7226 - loss: 0.5842 - val_accuracy: 0.5517 - val_loss: 0.7734
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.7200 - loss: 0.6369 - val_accuracy: 0.4828 - val_loss: 0.7617
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.7249 - loss: 0.5715 - val_accuracy: 0.4483 - val_loss: 0.8001
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6949 - loss: 0.5690 - val_accuracy: 0.4483 - val_loss: 0.8155
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.7099 - loss: 0.5595 - val_accuracy: 0.5862 - val_loss: 0.7930
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.7624 - loss: 0.5217 - val_accuracy: 0.5862 - val_loss: 0.7783
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7699 - loss: 0.4906 - val_accuracy: 0.5517 - val_loss: 0.7794
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.7650 - loss: 0.4723 - val_accuracy: 0.4828 - val_loss: 0.7862
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.7601 - loss: 0.5095 - val_accuracy: 0.5517 - val_loss: 0.7997
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.7673 - loss: 0.4412 - val_accuracy: 0.5517 - val_loss: 0.8312
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8025 - loss: 0.4118 - val_accuracy: 0.5862 - val_loss: 0.8849
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.8600 - loss: 0.3603 - val_accuracy: 0.5862 - val_loss: 0.9264
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.8199 - loss: 0.4050 - val_accuracy: 0.5517 - val_loss: 0.9314
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8025 - loss: 0.3499 - val_accuracy: 0.5862 - val_loss: 0.9230
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.8274 - loss: 0.3746 - val_accuracy: 0.5862 - val_loss: 0.8904
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8949 - loss: 0.2905 - val_accuracy: 0.5862 - val_loss: 0.9422
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.8574 - loss: 0.2980 - val_accuracy: 0.6207 - val_loss: 1.0592
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.8874 - loss: 0.2688 - val_accuracy: 0.6207 - val_loss: 1.1064
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.8724 - loss: 0.3126 - val_accuracy: 0.5862 - val_loss: 1.0593
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9301 - loss: 0.2460 - val_accuracy: 0.6207 - val_loss: 1.0397
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.9076 - loss: 0.2026 - val_accuracy: 0.5862 - val_loss: 1.0014
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9426 - loss: 0.1985 - val_accuracy: 0.6552 - val_loss: 0.9341
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9475 - loss: 0.1917 - val_accuracy: 0.6207 - val_loss: 0.9679
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.8900 - loss: 0.2447 - val_accuracy: 0.6207 - val_loss: 0.9975
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9400 - loss: 0.2373 - val_accuracy: 0.6207 - val_loss: 1.0308
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9050 - loss: 0.1778 - val_accuracy: 0.5517 - val_loss: 1.2405
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9024 - loss: 0.2428 - val_accuracy: 0.5517 - val_loss: 1.3665
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.8574 - loss: 0.2707 - val_accuracy: 0.6207 - val_loss: 1.2556
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9324 - loss: 0.1875 - val_accuracy: 0.6552 - val_loss: 1.1785
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9275 - loss: 0.1698 - val_accuracy: 0.6207 - val_loss: 1.1221
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9426 - loss: 0.1568 - val_accuracy: 0.7241 - val_loss: 1.1293
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9249 - loss: 0.1509 - val_accuracy: 0.6207 - val_loss: 0.9781
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9925 - loss: 0.0834 - val_accuracy: 0.6897 - val_loss: 0.9864
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9550 - loss: 0.1189 - val_accuracy: 0.6552 - val_loss: 1.0680
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9625 - loss: 0.1024 - val_accuracy: 0.6552 - val_loss: 1.1067
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9700 - loss: 0.0951 - val_accuracy: 0.6897 - val_loss: 1.1608
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9625 - loss: 0.1054 - val_accuracy: 0.6552 - val_loss: 1.2625
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9625 - loss: 0.0861 - val_accuracy: 0.6552 - val_loss: 1.3564
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9775 - loss: 0.0666 - val_accuracy: 0.6552 - val_loss: 1.4223
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9850 - loss: 0.0682 - val_accuracy: 0.6552 - val_loss: 1.4810
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9876 - loss: 0.0348 - val_accuracy: 0.6552 - val_loss: 1.5520
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.9775 - loss: 0.0655 - val_accuracy: 0.6552 - val_loss: 1.6045
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9925 - loss: 0.0232 - val_accuracy: 0.6552 - val_loss: 1.6955
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9850 - loss: 0.0383 - val_accuracy: 0.6552 - val_loss: 1.7726
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9850 - loss: 0.0487 - val_accuracy: 0.6552 - val_loss: 1.8191
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9925 - loss: 0.0291 - val_accuracy: 0.6207 - val_loss: 1.8287
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9925 - loss: 0.0236 - val_accuracy: 0.5862 - val_loss: 1.8580
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9850 - loss: 0.0338 - val_accuracy: 0.5862 - val_loss: 1.8447
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9775 - loss: 0.0342 - val_accuracy: 0.5862 - val_loss: 1.7501
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.9850 - loss: 0.0298 - val_accuracy: 0.5862 - val_loss: 1.6883
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.9925 - loss: 0.0439 - val_accuracy: 0.5862 - val_loss: 1.6582
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 0.9850 - loss: 0.0377 - val_accuracy: 0.5862 - val_loss: 1.7135
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0141 - val_accuracy: 0.6207 - val_loss: 1.7624
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.9850 - loss: 0.0323 - val_accuracy: 0.6207 - val_loss: 1.8413
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9850 - loss: 0.0327 - val_accuracy: 0.6207 - val_loss: 1.9365
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9850 - loss: 0.0489 - val_accuracy: 0.6207 - val_loss: 1.9227
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.6207 - val_loss: 1.8078
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9850 - loss: 0.0361 - val_accuracy: 0.6207 - val_loss: 1.6777
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.6207 - val_loss: 1.5729
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 0.9850 - loss: 0.0415 - val_accuracy: 0.6207 - val_loss: 1.5350
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.9925 - loss: 0.0224 - val_accuracy: 0.7241 - val_loss: 1.6168
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 13s 1s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.7241 - val_loss: 1.8020
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9850 - loss: 0.0483 - val_accuracy: 0.7241 - val_loss: 1.8302
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.6897 - val_loss: 1.8002
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9925 - loss: 0.0169 - val_accuracy: 0.6552 - val_loss: 1.7535
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.6207 - val_loss: 1.7766
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9925 - loss: 0.0118 - val_accuracy: 0.6552 - val_loss: 1.8200
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 2s/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.6552 - val_loss: 1.8569
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.6552 - val_loss: 1.9211
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.9925 - loss: 0.0349 - val_accuracy: 0.6552 - val_loss: 2.0166
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.6552 - val_loss: 2.1282
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9850 - loss: 0.0309 - val_accuracy: 0.6552 - val_loss: 2.1536
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6552 - val_loss: 2.1655
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9850 - loss: 0.0226 - val_accuracy: 0.6552 - val_loss: 2.1005
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9925 - loss: 0.0091 - val_accuracy: 0.6207 - val_loss: 1.9823
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9775 - loss: 0.0358 - val_accuracy: 0.6552 - val_loss: 1.8656
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.9925 - loss: 0.0276 - val_accuracy: 0.6552 - val_loss: 1.7798
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.6552 - val_loss: 1.7182
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6552 - val_loss: 1.6975
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.6552 - val_loss: 1.6960
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.9850 - loss: 0.0210 - val_accuracy: 0.7241 - val_loss: 1.7706
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.9850 - loss: 0.0260 - val_accuracy: 0.6552 - val_loss: 1.8993

# %%
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"])
ax.set_title("validation loss")
ax.set_xlabel("epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["val_accuracy"])
ax2.set_title("validation accuracy")
ax2.set_xlabel("epochs")
ax2.set_ylim(0, 1)

plt.show()

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 2.428842306137085
# Test accuracy: 0.6000000238418579

# %%
vgg = keras.applications.VGG16(weights='imagenet', include_top=True)
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc2 (Dense)                          │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ predictions (Dense)                  │ (None, 1000)                │       4,097,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 138,357,544 (527.79 MB)
#  Trainable params: 138,357,544 (527.79 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# make a reference to VGG's input layer
inp = vgg.input

# make a new softmax layer with num_classes neurons
new_classification_layer = Dense(num_classes, activation='softmax')

# connect our new layer to the second to last layer in VGG, and make a reference to it
out = new_classification_layer(vgg.layers[-2].output)

# create a new network between inp and out
model_new = Model(inp, out)

# %%
# make all layers untrainable by freezing weights (except for last layer)
for l, layer in enumerate(model_new.layers[:-1]):
    layer.trainable = False

# ensure the last layer is trainable/not frozen
for l, layer in enumerate(model_new.layers[-1:]):
    layer.trainable = True

model_new.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_new.summary()
# Out:
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 4096)                │     102,764,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc2 (Dense)                          │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │          16,388 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 134,276,932 (512.23 MB)
#  Trainable params: 16,388 (64.02 KB)
#  Non-trainable params: 134,260,544 (512.16 MB)

# %%
history2 = model_new.fit(x_train, y_train,
                         batch_size=128,
                         epochs=100,
                         validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 110s 25s/step - accuracy: 0.4099 - loss: 1.2538 - val_accuracy: 0.6207 - val_loss: 0.8533
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 158s 25s/step - accuracy: 0.4726 - loss: 1.1711 - val_accuracy: 0.3448 - val_loss: 0.8059
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 128s 27s/step - accuracy: 0.5052 - loss: 0.8486 - val_accuracy: 0.3793 - val_loss: 0.9699
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 138s 25s/step - accuracy: 0.4951 - loss: 0.9432 - val_accuracy: 0.6207 - val_loss: 0.6725
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.4850 - loss: 0.8594 - val_accuracy: 0.5862 - val_loss: 0.6658
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 151s 25s/step - accuracy: 0.5098 - loss: 0.8626 - val_accuracy: 0.3448 - val_loss: 0.7679
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 135s 26s/step - accuracy: 0.5150 - loss: 0.8454 - val_accuracy: 0.3448 - val_loss: 0.8294
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 25s/step - accuracy: 0.5101 - loss: 0.8643 - val_accuracy: 0.5517 - val_loss: 0.6490
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 27s/step - accuracy: 0.5574 - loss: 0.8385 - val_accuracy: 0.6207 - val_loss: 0.6726
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 140s 26s/step - accuracy: 0.4801 - loss: 0.9664 - val_accuracy: 0.5862 - val_loss: 0.6423
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 119s 26s/step - accuracy: 0.6126 - loss: 0.7801 - val_accuracy: 0.3793 - val_loss: 0.9629
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 132s 27s/step - accuracy: 0.5072 - loss: 0.9321 - val_accuracy: 0.3793 - val_loss: 1.0829
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 25s/step - accuracy: 0.5098 - loss: 0.9905 - val_accuracy: 0.3793 - val_loss: 0.8074
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 168s 46s/step - accuracy: 0.5274 - loss: 0.7781 - val_accuracy: 0.6897 - val_loss: 0.6137
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 130s 25s/step - accuracy: 0.6201 - loss: 0.7254 - val_accuracy: 0.6897 - val_loss: 0.6106
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 114s 25s/step - accuracy: 0.6723 - loss: 0.6938 - val_accuracy: 0.4483 - val_loss: 0.7815
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 26s/step - accuracy: 0.5522 - loss: 0.7169 - val_accuracy: 0.3793 - val_loss: 1.0353
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.5150 - loss: 0.8377 - val_accuracy: 0.4483 - val_loss: 0.9027
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 25s/step - accuracy: 0.5375 - loss: 0.7576 - val_accuracy: 0.6897 - val_loss: 0.7178
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 113s 26s/step - accuracy: 0.6550 - loss: 0.7325 - val_accuracy: 0.7241 - val_loss: 0.6338
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 110s 26s/step - accuracy: 0.6599 - loss: 0.6863 - val_accuracy: 0.7241 - val_loss: 0.6013
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 140s 23s/step - accuracy: 0.6775 - loss: 0.6473 - val_accuracy: 0.7241 - val_loss: 0.5894
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 144s 27s/step - accuracy: 0.6674 - loss: 0.6538 - val_accuracy: 0.6552 - val_loss: 0.6198
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.7073 - loss: 0.6446 - val_accuracy: 0.5862 - val_loss: 0.6416
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 27s/step - accuracy: 0.7024 - loss: 0.6492 - val_accuracy: 0.6552 - val_loss: 0.6347
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 140s 25s/step - accuracy: 0.7073 - loss: 0.6523 - val_accuracy: 0.6897 - val_loss: 0.6292
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 144s 27s/step - accuracy: 0.7376 - loss: 0.6477 - val_accuracy: 0.6552 - val_loss: 0.6658
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 110s 26s/step - accuracy: 0.6926 - loss: 0.6559 - val_accuracy: 0.6552 - val_loss: 0.6169
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 26s/step - accuracy: 0.7324 - loss: 0.6423 - val_accuracy: 0.7586 - val_loss: 0.5655
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.6625 - loss: 0.6652 - val_accuracy: 0.6897 - val_loss: 0.5727
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 27s/step - accuracy: 0.6975 - loss: 0.6445 - val_accuracy: 0.7241 - val_loss: 0.6080
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 161s 46s/step - accuracy: 0.7474 - loss: 0.6222 - val_accuracy: 0.6897 - val_loss: 0.6477
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 122s 26s/step - accuracy: 0.7552 - loss: 0.6207 - val_accuracy: 0.6207 - val_loss: 0.6863
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 26s/step - accuracy: 0.7001 - loss: 0.6241 - val_accuracy: 0.6897 - val_loss: 0.5656
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.7151 - loss: 0.6127 - val_accuracy: 0.7586 - val_loss: 0.5545
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 27s/step - accuracy: 0.6775 - loss: 0.6290 - val_accuracy: 0.5862 - val_loss: 0.7436
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 25s/step - accuracy: 0.6377 - loss: 0.6281 - val_accuracy: 0.3793 - val_loss: 0.9958
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 144s 26s/step - accuracy: 0.5251 - loss: 0.7627 - val_accuracy: 0.7241 - val_loss: 0.6056
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 158s 46s/step - accuracy: 0.7774 - loss: 0.5638 - val_accuracy: 0.6207 - val_loss: 0.6246
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 123s 25s/step - accuracy: 0.5173 - loss: 0.7977 - val_accuracy: 0.6207 - val_loss: 0.5858
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 27s/step - accuracy: 0.5875 - loss: 0.6925 - val_accuracy: 0.4138 - val_loss: 0.7876
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 25s/step - accuracy: 0.6100 - loss: 0.6273 - val_accuracy: 0.3793 - val_loss: 1.2161
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.5098 - loss: 0.8909 - val_accuracy: 0.5862 - val_loss: 0.7805
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 26s/step - accuracy: 0.6573 - loss: 0.6025 - val_accuracy: 0.7241 - val_loss: 0.5629
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 25s/step - accuracy: 0.6201 - loss: 0.6320 - val_accuracy: 0.6552 - val_loss: 0.5728
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 27s/step - accuracy: 0.6028 - loss: 0.6485 - val_accuracy: 0.6207 - val_loss: 0.7044
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 140s 25s/step - accuracy: 0.7076 - loss: 0.5668 - val_accuracy: 0.3793 - val_loss: 1.1175
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 25s/step - accuracy: 0.5098 - loss: 0.8163 - val_accuracy: 0.4138 - val_loss: 0.8458
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 25s/step - accuracy: 0.6123 - loss: 0.6315 - val_accuracy: 0.7586 - val_loss: 0.5481
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 23s/step - accuracy: 0.7102 - loss: 0.5571 - val_accuracy: 0.6207 - val_loss: 0.5632
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 24s/step - accuracy: 0.6149 - loss: 0.6371 - val_accuracy: 0.7241 - val_loss: 0.5867
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 145s 27s/step - accuracy: 0.8228 - loss: 0.5166 - val_accuracy: 0.4138 - val_loss: 0.8521
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 106s 25s/step - accuracy: 0.5927 - loss: 0.6278 - val_accuracy: 0.6207 - val_loss: 0.6913
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 108s 27s/step - accuracy: 0.7575 - loss: 0.5416 - val_accuracy: 0.7241 - val_loss: 0.5719
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 161s 46s/step - accuracy: 0.6949 - loss: 0.5710 - val_accuracy: 0.7931 - val_loss: 0.5966
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 125s 25s/step - accuracy: 0.7624 - loss: 0.5485 - val_accuracy: 0.6552 - val_loss: 0.7030
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 25s/step - accuracy: 0.7826 - loss: 0.5373 - val_accuracy: 0.7241 - val_loss: 0.5724
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.8025 - loss: 0.5033 - val_accuracy: 0.6207 - val_loss: 0.5969
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 145s 25s/step - accuracy: 0.5650 - loss: 0.6783 - val_accuracy: 0.6897 - val_loss: 0.5577
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 25s/step - accuracy: 0.6697 - loss: 0.5822 - val_accuracy: 0.6207 - val_loss: 0.7107
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.7278 - loss: 0.5417 - val_accuracy: 0.5172 - val_loss: 0.7835
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 25s/step - accuracy: 0.6648 - loss: 0.5714 - val_accuracy: 0.7931 - val_loss: 0.5442
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 24s/step - accuracy: 0.7852 - loss: 0.4995 - val_accuracy: 0.7586 - val_loss: 0.5374
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.7774 - loss: 0.4994 - val_accuracy: 0.6207 - val_loss: 0.6351
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.8127 - loss: 0.4975 - val_accuracy: 0.6207 - val_loss: 0.6520
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 145s 25s/step - accuracy: 0.7774 - loss: 0.5065 - val_accuracy: 0.7241 - val_loss: 0.5825
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 25s/step - accuracy: 0.8450 - loss: 0.4805 - val_accuracy: 0.7241 - val_loss: 0.5728
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 106s 25s/step - accuracy: 0.8551 - loss: 0.4751 - val_accuracy: 0.7241 - val_loss: 0.5912
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 145s 25s/step - accuracy: 0.8450 - loss: 0.4782 - val_accuracy: 0.6207 - val_loss: 0.6510
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.7549 - loss: 0.5017 - val_accuracy: 0.6552 - val_loss: 0.6995
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 27s/step - accuracy: 0.7275 - loss: 0.5210 - val_accuracy: 0.7241 - val_loss: 0.5588
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 140s 25s/step - accuracy: 0.8551 - loss: 0.4667 - val_accuracy: 0.7586 - val_loss: 0.5164
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 145s 25s/step - accuracy: 0.7725 - loss: 0.5000 - val_accuracy: 0.7586 - val_loss: 0.5162
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 26s/step - accuracy: 0.8225 - loss: 0.4745 - val_accuracy: 0.6897 - val_loss: 0.6576
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 23s/step - accuracy: 0.7803 - loss: 0.4981 - val_accuracy: 0.6552 - val_loss: 0.7370
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 25s/step - accuracy: 0.7099 - loss: 0.5360 - val_accuracy: 0.6897 - val_loss: 0.5472
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 27s/step - accuracy: 0.8675 - loss: 0.4534 - val_accuracy: 0.7586 - val_loss: 0.5187
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 26s/step - accuracy: 0.8274 - loss: 0.4613 - val_accuracy: 0.7241 - val_loss: 0.5589
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 26s/step - accuracy: 0.8753 - loss: 0.4425 - val_accuracy: 0.6552 - val_loss: 0.6310
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 140s 24s/step - accuracy: 0.8401 - loss: 0.4660 - val_accuracy: 0.7241 - val_loss: 0.5391
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 25s/step - accuracy: 0.8649 - loss: 0.4471 - val_accuracy: 0.7586 - val_loss: 0.5163
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.7950 - loss: 0.4652 - val_accuracy: 0.7586 - val_loss: 0.5327
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 25s/step - accuracy: 0.8574 - loss: 0.4424 - val_accuracy: 0.7241 - val_loss: 0.5618
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.8626 - loss: 0.4361 - val_accuracy: 0.7586 - val_loss: 0.5260
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 23s/step - accuracy: 0.8251 - loss: 0.4506 - val_accuracy: 0.7931 - val_loss: 0.5282
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 108s 26s/step - accuracy: 0.7125 - loss: 0.4997 - val_accuracy: 0.7586 - val_loss: 0.5263
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 27s/step - accuracy: 0.8600 - loss: 0.4332 - val_accuracy: 0.6897 - val_loss: 0.6707
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 25s/step - accuracy: 0.7898 - loss: 0.4773 - val_accuracy: 0.6897 - val_loss: 0.7353
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 144s 25s/step - accuracy: 0.7125 - loss: 0.5039 - val_accuracy: 0.7586 - val_loss: 0.5384
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 26s/step - accuracy: 0.8476 - loss: 0.4294 - val_accuracy: 0.7931 - val_loss: 0.5245
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 109s 25s/step - accuracy: 0.7099 - loss: 0.5059 - val_accuracy: 0.7586 - val_loss: 0.5121
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 27s/step - accuracy: 0.8048 - loss: 0.4492 - val_accuracy: 0.6552 - val_loss: 0.6172
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 23s/step - accuracy: 0.8577 - loss: 0.4454 - val_accuracy: 0.6897 - val_loss: 0.6840
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 141s 25s/step - accuracy: 0.7725 - loss: 0.4737 - val_accuracy: 0.7241 - val_loss: 0.5323
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 142s 25s/step - accuracy: 0.8574 - loss: 0.4217 - val_accuracy: 0.7931 - val_loss: 0.5147
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 106s 25s/step - accuracy: 0.7725 - loss: 0.4538 - val_accuracy: 0.6552 - val_loss: 0.5688
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 143s 25s/step - accuracy: 0.8626 - loss: 0.4262 - val_accuracy: 0.6552 - val_loss: 0.6747
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 107s 25s/step - accuracy: 0.7725 - loss: 0.4543 - val_accuracy: 0.7586 - val_loss: 0.5116
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 144s 25s/step - accuracy: 0.8450 - loss: 0.4285 - val_accuracy: 0.6552 - val_loss: 0.5997
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 139s 24s/step - accuracy: 0.5950 - loss: 0.6317 - val_accuracy: 0.7586 - val_loss: 0.5240

# %%
fig = plt.figure(figsize=(16,4))
ax = fig.add_subplot(121)
ax.plot(history.history["val_loss"])
ax.plot(history2.history["val_loss"])
ax.set_title("validation loss")
ax.set_xlabel("epochs")

ax2 = fig.add_subplot(122)
ax2.plot(history.history["accuracy"])
ax2.plot(history2.history["accuracy"])
ax2.set_title("validation accuracy")
ax2.set_xlabel("epochs")
ax2.set_ylim(0, 1)

plt.show()

# %%
loss, accuracy = model_new.evaluate(x_test, y_test, verbose=0)

print('Test loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# Test loss: 0.7681795954704285
# Test accuracy: 0.5666666626930237

# %%
img, y = get_image('/content/drive/MyDrive/imagens/testes/imagem-teste-2.jpg')
probabilities = model_new.predict([x])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_211
# Received: inputs=('Tensor(shape=(1, 224, 224, 3))',)
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
